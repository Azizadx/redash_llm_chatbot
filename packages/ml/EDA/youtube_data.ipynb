# %%
from sqlalchemy import create_engine
import pandas as pd 


# Database credentials
username = 'redash2'
password = 'redashpssd'
host = 'localhost'
port = '5440'
database = 'redashDB'


# SQLAlchemy engine
engine = create_engine(f'postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}')

# %%
def read_csv_to_df(csv_path, table_name):
    df = pd.read_csv(csv_path)

    # Use a context manager to ensure the connection is closed
    with engine.connect() as connection:
        df.to_sql(table_name, connection, if_exists='replace', index=False)

    return df

# %% [markdown]
#  video viewership data across various cities.

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Cities/Chart _ata.csv'
table_name = 'cities_chart_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#             Date                                 Cities    City name  Views
# 0     2020-06-28  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa      0
# 1     2020-06-29  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa      0
# 2     2020-06-30  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa      0
# 3     2020-07-01  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa      0
# 4     2020-07-02  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa      0
# ...          ...                                    ...          ...    ...
# 6390  2023-12-24  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester      0
# 6391  2023-12-25  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester      0
# 6392  2023-12-26  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester      0
# 6393  2023-12-27  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester      0
# 6394  2023-12-28  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester      0
#
# [6395 rows x 4 columns]

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Cities/Table data.csv'
table_name = 'cities_table_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#                                   Cities    City name Geography Geography.1  \
# 0                                  Total          NaN       NaN         NaN
# 1  0x164b85cef5ab402d:0x8467b6b037a24d49  Addis Ababa        ET       ET-AA
# 2  0x487a4d4c5226f5db:0xd9be143804fe6baa   Manchester        GB      GB-ENG
# 3  0x3568eb6de823cd35:0x35d8cb74247108a7        Busan        KR       KR-26
# 4  0x168e8fde9837cabf:0x191f55de7e67db40     Khartoum        SD       SD-KH
# 5  0x3397ba0942ef7375:0x4a9a32d9fe083d40  Quezon City        PH       PH-00
# 6  0x3ae253d10f7a7003:0x320b2e4d32d3838d      Colombo        LK        LK-1
# 7  0x102354e509f894f7:0xc8fde921f89849f6      Cotonou        BJ       BJ-LI
# 8  0x399bfd991f32b16b:0x93ccba8909978be7      Lucknow        IN       IN-UP
#
#    Views  Watch time (hours) Average view duration
# 0  26625           2157.3497               0:04:51
# 1   1252            127.5042               0:06:06
# 2     23              0.0402               0:00:06
# ...

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Cities/Totals.csv'
table_name = 'cities_total_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#             Date  Views
# 0     2020-06-28      1
# 1     2020-06-29     72
# 2     2020-06-30     76
# 3     2020-07-01     70
# 4     2020-07-02     57
# ...          ...    ...
# 1274  2023-12-24     36
# 1275  2023-12-25     24
# 1276  2023-12-26     57
# 1277  2023-12-27      8
# 1278  2023-12-28     25
#
# [1279 rows x 2 columns]

# %% [markdown]
#  daily views for atenacademy youtube video, categorized by geography

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Geography/Chart data.csv'
table_name = 'Geography_chart_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#              Date Geography  Views
# 0      2020-06-28        BJ      0
# 1      2020-06-29        BJ      0
# 2      2020-06-30        BJ      0
# 3      2020-07-01        BJ      0
# 4      2020-07-02        BJ      0
# ...           ...       ...    ...
# 37086  2023-12-24        ZA      0
# 37087  2023-12-25        ZA      0
# 37088  2023-12-26        ZA      0
# 37089  2023-12-27        ZA      0
# 37090  2023-12-28        ZA      0
#
# [37091 rows x 3 columns]

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Geography/Table data.csv'
table_name = 'Geography_table_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#    Geography  Views  Watch time (hours) Average view duration
# 0      Total  26625           2157.3497               0:04:51
# 1         ET  10903            958.4972               0:05:16
# 2         NG    854            103.8847               0:07:17
# 3         KE    460             48.0795               0:06:16
# 4         US    260             11.6346               0:02:41
# 5         IN    228              2.1819               0:00:34
# 6         RW    221             20.7627               0:05:38
# 7         DE    173              2.3868               0:00:49
# 8         ZA    154              2.0188               0:00:47
# 9         BJ    134             10.4045               0:04:39
# 10        SD    116              8.1711               0:04:13
# 11        GB    112              0.8712               0:00:28
# 12        RO     83              1.0051               0:00:43
# 13        GH     61              8.1040               0:07:58
# ...

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Geography/Totals.csv'
table_name = 'Geography_total_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#             Date  Views
# 0     2020-06-28      1
# 1     2020-06-29     72
# 2     2020-06-30     76
# 3     2020-07-01     70
# 4     2020-07-02     57
# ...          ...    ...
# 1274  2023-12-24     36
# 1275  2023-12-25     24
# 1276  2023-12-26     57
# 1277  2023-12-27      8
# 1278  2023-12-28     25
#
# [1279 rows x 2 columns]

# %% [markdown]
# analysis of video content viewership segmented by the age of viewers.

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Viewer age/Table data.csv'
table_name = 'Viewer age'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#     Viewer age  Views (%) Average view duration  \
# 0  13–17 years       0.49               0:00:08
# 1  18–24 years      23.27               0:05:17
# 2  25–34 years      72.70               0:04:30
# 3  35–44 years       3.54               0:01:49
#
#    Average percentage viewed (%)  Watch time (hours) (%)
# 0                           0.27                    0.01
# 1                           9.75                   26.91
# 2                           8.08                   71.66
# 3                           2.83                    1.42

# %% [markdown]
# video content viewership segmented by viewer gender

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Viewer gender/Table data.csv'
table_name = 'Viewer_gender_table_data'
df = read_csv_to_df(csv_path,table_name)
df
# Out:
#   Viewer gender  Views (%) Average view duration  \
# 0        Female      20.16               0:05:23
# 1          Male      79.84               0:04:27
#
#    Average percentage viewed (%)  Watch time (hours) (%)
# 0                           9.36                   23.38
# 1                           7.83                   76.62

# %% [markdown]
# data on the sources of subscribers for a YouTube channel

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Subscription source/Chart data.csv'
table_name = 'Subscription_source_ chart_data'
df = read_csv_to_df(csv_path,table_name)
df

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Subscription source/Table data.csv'
table_name = 'Subscription_source_ table_data'
df = read_csv_to_df(csv_path,table_name)
df

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Subscription source/Totals.csv'
table_name = 'Subscription_source_ total_data'
df = read_csv_to_df(csv_path,table_name)
df

# %% [markdown]
# daily viewership data for a ten academy YouTube channel, specifically focusing on views from subscribed users

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Subscription status/Chart data.csv'
table_name = 'Subscription_status_ chart_data'
df = read_csv_to_df(csv_path,table_name)
df

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Subscription status/Table data.csv'
table_name = 'Subscription_status_ table_data'
df = read_csv_to_df(csv_path,table_name)
df

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Subscription status/Totals.csv'
table_name = 'Subscription_status_ total_data'
df = read_csv_to_df(csv_path,table_name)
df

# %% [markdown]
# viewership statistics for a tenacadeny youtube channel

# %%
csv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Viewership by Date/Table data.csv'
table_name = 'Viewership by Date_table_data'
df = read_csv_to_df(csv_path,table_name)
df

# %%
sv_path = '/home/meron/Documents/work/tenacademy/week3/redash_llm_chatbot/packages/ml/youtube-data/Viewership by Date/Totals.csv'
table_name = 'Viewership by Date_totals_data'
df = read_csv_to_df(csv_path,table_name)
df
